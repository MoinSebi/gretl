# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
f = "../data/test/yeast/stats/stats.path2.tsv"

# %%
df = pd.read_csv(f, sep = "\t")

# %%
df.index = df["Path"]

# %%
df
# Out:
#                   Path  Sequence [bp]  Nodes  Unique edges  Directed nodes  \
# Path
# ABQ_6.ChrX  ABQ_6.ChrX         960543  17297         17297           17297
# BIH_4.ChrX  BIH_4.ChrX         960543  17042         17042           17042
# ABF_6.ChrX  ABF_6.ChrX         960543  17351         17344           17344
# BPN_2.ChrX  BPN_2.ChrX         960543  15698         15667           15667
# BCK_8.ChrX  BCK_8.ChrX         960543  16674         16674           16674
#
#             Edges  Unique Edges  Unique nodes  Unique nodes [bp]  \
# Path
# ABQ_6.ChrX  17296         17296         17297             735020
# BIH_4.ChrX  17041         17041         17042             711864
# ABF_6.ChrX  17350         17344         17344             720571
# BPN_2.ChrX  15697         15669         15667             719040
# BCK_8.ChrX  16673         16673         16674             725351
#
#             Unique nodes (normalized)  ...  Depth std (normalized)  \
# Path                                   ...
# ABQ_6.ChrX                   1.000000  ...                0.189474
# BIH_4.ChrX                   1.000000  ...                0.183080
# ABF_6.ChrX                   0.999597  ...                0.274178
# BPN_2.ChrX                   0.998025  ...                0.239306
# BCK_8.ChrX                   1.000000  ...                0.311607
#
#             Similarity average  Similarity median  Similarity std  \
# Path
# ABQ_6.ChrX            4.178066                  4        0.946006
# BIH_4.ChrX            4.207722                  3        0.913802
# ABF_6.ChrX            3.868595                  3        1.369922
# BPN_2.ChrX            4.103580                  4        1.195332
# BCK_8.ChrX            3.692455                  1        1.556711
#
#             Similarity average (normalized)  Similarity median (normalized)  \
# Path
# ABQ_6.ChrX                         0.835613                             0.8
# BIH_4.ChrX                         0.841544                             0.6
# ABF_6.ChrX                         0.773719                             0.6
# BPN_2.ChrX                         0.820716                             0.8
# BCK_8.ChrX                         0.738491                             0.2
#
#             Similarity std (normalized)  Degree average  Degree median  \
# Path
# ABQ_6.ChrX                     0.189201        3.038330              2
# BIH_4.ChrX                     0.182760        3.038493              2
# ABF_6.ChrX                     0.273984        3.035272              2
# BPN_2.ChrX                     0.239066        3.037584              2
# BCK_8.ChrX                     0.311342        3.036464              2
#
#             Degree std
# Path
# ABQ_6.ChrX    1.009167
# BIH_4.ChrX    1.009425
# ABF_6.ChrX    1.010190
# BPN_2.ChrX    1.011144
# BCK_8.ChrX    1.012037
#
# [5 rows x 38 columns]

# %%
df.index = [x.split(".")[0] for x in df.index]

# %%
import matplotlib as mpl
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
plt.figure(figsize = (5,4))
plt.scatter(data=df, x="Edges", y="Jumps total", edgecolor = "black", color = "royalblue")
for x in df.iterrows(): 
    plt.annotate(x[0], (x[1]["Edges"] + 0.0005, x[1]["Jumps total"]))
plt.ylabel("Edges")
plt.xlabel("Jumps total")
plt.tight_layout()
#plt.savefig("plots/stats.path.scatter.pdf")
