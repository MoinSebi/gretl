# %%
# Imports
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
# Path-centric statistics
f = "../data/test/yeast/stats/yeast.chr5.path2.tsv"

# %%
# Read tsv with pandas
df = pd.read_csv(f, sep = "\t")

# %%
# Reset the index
df.index = df["Path"]
df.index = [x.split(".")[0] for x in df.index]

# %%
# Check the data
df
# Out:
#              Path  Sequence [bp]  Covered sequence [%]  Nodes  Unique edges  \
# ABQ_6  ABQ_6.ChrX         735020              0.765213  17297         17297
# BIH_4  BIH_4.ChrX         711864              0.741106  17042         17042
# ABF_6  ABF_6.ChrX         720629              0.750231  17351         17351
# BPN_2  BPN_2.ChrX         720206              0.749790  15698         15698
# BCK_8  BCK_8.ChrX         725351              0.755147  16674         16674
#
#        Directed nodes  Edges  Unique Edges  Unique nodes  Unique nodes [bp]  \
# ABQ_6           17297  17296         17296         17297             735020
# BIH_4           17042  17041         17041         17042             711864
# ABF_6           17351  17350         17344         17344             720571
# BPN_2           15698  15697         15669         15667             719040
# BCK_8           16674  16673         16673         16674             725351
#
#        ...  Depth std (normalized)  Similarity average  Similarity median  \
# ABQ_6  ...                0.189474            4.178066                  4
# BIH_4  ...                0.183080            4.207722                  4
# ABF_6  ...                0.274178            3.868595                  4
# BPN_2  ...                0.239306            4.103580                  4
# BCK_8  ...                0.311607            3.692455                  4
#
#        Similarity std  Similarity average (normalized)  \
# ABQ_6        0.946006                         0.835613
# BIH_4        0.913802                         0.841544
# ABF_6        1.369922                         0.773719
# BPN_2        1.195332                         0.820716
# BCK_8        1.556711                         0.738491
#
#        Similarity median (normalized)  Similarity std (normalized)  \
# ABQ_6                             0.8                     0.189201
# BIH_4                             0.8                     0.182760
# ABF_6                             0.8                     0.273984
# BPN_2                             0.8                     0.239066
# BCK_8                             0.8                     0.311342
#
#        Degree average  Degree median  Degree std
# ABQ_6        3.038330              4    1.009167
# BIH_4        3.038493              4    1.009425
# ABF_6        3.035272              4    1.010190
# BPN_2        3.037584              4    1.011144
# BCK_8        3.036464              4    1.012037
#
# [5 rows x 39 columns]

# %%
# Update plotting parameters
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
# Plot the example using "Egdes" and "Jumpts total"
plt.figure(figsize = (5,4))
plt.scatter(data=df, x="Edges", y="Jumps total", edgecolor = "black", color = "royalblue")
for x in df.iterrows(): 
    plt.annotate(x[0], (x[1]["Edges"] + 0.0005, x[1]["Jumps total"]))
plt.xlabel("Edges")
plt.ylabel("Jumps total")
plt.tight_layout()
#plt.savefig("plots/stats.path.scatter.pdf")

# %%
# Plot the example using "Egdes" and "Jumpts total"
plt.figure(figsize = (5,4))
plt.scatter(data=df, x="Edges", y="Depth average", edgecolor = "black", color = "royalblue")
for x in df.iterrows():
    plt.annotate(x[0], (x[1]["Edges"] + 0.0005, x[1]["Depth average"]))
plt.xlabel("Edges")
plt.ylabel("Depth average")
plt.tight_layout()

# %%
df
# Out:
#              Path  Sequence [bp]  Covered sequence [%]  Nodes  Unique edges  \
# ABQ_6  ABQ_6.ChrX         735020              0.765213  17297         17297
# BIH_4  BIH_4.ChrX         711864              0.741106  17042         17042
# ABF_6  ABF_6.ChrX         720629              0.750231  17351         17351
# BPN_2  BPN_2.ChrX         720206              0.749790  15698         15698
# BCK_8  BCK_8.ChrX         725351              0.755147  16674         16674
#
#        Directed nodes  Edges  Unique Edges  Unique nodes  Unique nodes [bp]  \
# ABQ_6           17297  17296         17296         17297             735020
# BIH_4           17042  17041         17041         17042             711864
# ABF_6           17351  17350         17344         17344             720571
# BPN_2           15698  15697         15669         15667             719040
# BCK_8           16674  16673         16673         16674             725351
#
#        ...  Depth std (normalized)  Similarity average  Similarity median  \
# ABQ_6  ...                0.189474            4.178066                  4
# BIH_4  ...                0.183080            4.207722                  4
# ABF_6  ...                0.274178            3.868595                  4
# BPN_2  ...                0.239306            4.103580                  4
# BCK_8  ...                0.311607            3.692455                  4
#
#        Similarity std  Similarity average (normalized)  \
# ABQ_6        0.946006                         0.835613
# BIH_4        0.913802                         0.841544
# ABF_6        1.369922                         0.773719
# BPN_2        1.195332                         0.820716
# BCK_8        1.556711                         0.738491
#
#        Similarity median (normalized)  Similarity std (normalized)  \
# ABQ_6                             0.8                     0.189201
# BIH_4                             0.8                     0.182760
# ABF_6                             0.8                     0.273984
# BPN_2                             0.8                     0.239066
# BCK_8                             0.8                     0.311342
#
#        Degree average  Degree median  Degree std
# ABQ_6        3.038330              4    1.009167
# BIH_4        3.038493              4    1.009425
# ABF_6        3.035272              4    1.010190
# BPN_2        3.037584              4    1.011144
# BCK_8        3.036464              4    1.012037
#
# [5 rows x 39 columns]
