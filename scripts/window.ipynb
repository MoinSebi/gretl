# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Example file
f = "../data/test/yeast/analysis/analysis.window.txt"

# %%
# Read the file using pandas
df = pd.read_csv(f, sep = "\t", header = None)

# %%
# Set new index
df.set_index(0, inplace=True)

# %%
# Show the dataframe that everything looks how it is supposed to
df
# Out:
#             1    2    3      4       5       6       7       8       9    \
# 0
# ABQ_6.ChrX    1    1    1  1.000  1.3350  3.1446  2.9856  3.9458  3.9902
# BIH_4.ChrX    1    1    1  1.000  1.3256  3.1478  2.9862  3.9438  3.9910
# ABF_6.ChrX    1    1    1  1.194  1.8298  2.9204  2.9640  3.7838  3.9866
# BPN_2.ChrX    1    1    1  1.000  1.6568  1.9002  1.0000  1.0000  1.0000
# BCK_8.ChrX    1    1    1  1.194  1.0000  1.0000  1.0000  3.7628  3.9854
#
#                10   ...     139     140     141     142       143     144  \
# 0                   ...
# ABQ_6.ChrX  3.9912  ...  4.8978  4.9730  4.6540  4.9754  4.980600  3.3442
# BIH_4.ChrX  3.9920  ...  4.9688  4.4988  4.9782  4.9818  4.684013     NaN
# ABF_6.ChrX  3.9854  ...  4.9542  4.9430  4.8060  4.6214  4.968800  4.5946
# BPN_2.ChrX  1.0000  ...  4.8664  4.8842  4.9504  4.8134  4.977200  4.9392
# BCK_8.ChrX  3.9872  ...  4.9404  4.9438  4.8160  4.8428  4.974400  4.2200
#
#                  145       146  147  148
# 0
# ...

# %%
# Plot the figure
plt.figure(figsize=(10, 6))  # Set the figure size
sns.heatmap(df, cmap="coolwarm", cbar_kws={'label': 'Similarity'})
plt.tight_layout(rect=[0.05, 0.05, 0.85, 0.95])  # Adjust as needed
plt.xlabel("Sequence window [x 5 kb]")
#plt.savefig("plots/analysis.window.pdf")
# Out:
# Text(0.5, 24.222222222222207, 'Sequence window [x 5 kb]')
